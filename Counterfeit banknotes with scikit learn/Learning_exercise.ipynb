# %% [markdown]
# # 🏦 Banknotes Classification Exercise
#
# In this exercise, you will practice the basics of supervised machine learning with scikit-learn using a real-world inspired dataset. The dataset banknotes.csv contains measurements extracted from images of genuine and counterfeit banknotes. Your task is to train a machine learning model to distinguish between Authentic and Counterfeit notes.
#
# ### What you will learn
#
# - How to load and preprocess data from a CSV file.
#
# - How to split data into training and testing sets.
#
# - How to train different classifiers (Perceptron, Support Vector Machine, k-Nearest Neighbors).
#
# - How to make predictions on unseen data.
#
# - How to evaluate model accuracy and compare performance across models.
#
# ### Dataset
#
# Each row in banknotes.csv contains four numerical features (derived from image analysis of banknotes) and a label:
#
# - **Evidence** (features): Four floating-point values describing statistical properties of the note.
#
# - **Label** (target): Authentic or Counterfeit.
#
# ### Your task
#
# - Choose a model from scikit-learn (start with the Perceptron, but feel free to try others).
#
# - Train the model on the training set.
#
# - Evaluate its accuracy on the test set.
#
# - Experiment by switching models and comparing results.

# %%
import csv
import random

from sklearn import svm
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Initialize the model. You can choose among different model classes:
#
# Perceptron: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Perceptron.html
#
# SVM: https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC
#
# K-neighbor classifier: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html

# %%
model = Perceptron()
# model = svm.SVC()
# model = KNeighborsClassifier(n_neighbors=1)
# model = GaussianNB()

# %% [markdown]
# Read data from file, 'banknotes.csv'. Each example will have 4 input features, the 'evidence' and 1 target feature, the 'label'. Create two lists, evidence and labels. The evidence list will be a list of lists, as each entry will be a list of 4 elements.

# %%
# TO DO

# Read the data and extract the evidence and labels

# %% [markdown]
# Split the data into training and testing sets. Choose a 0.4 split: this means, 60% of your data (evidence + labels) will be in the training set, and 40% in the testing set. You can do so manually, or by using train_test_split by scikit learn:
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
# TO DO

# Split the data into training and test split

# %% [markdown]
# Fit the model. This is the 'training phase'. You fit the model to your training data. Read the documentation of the model classes. You will find a 'fit' method.

# %%
# TO DO

# Fit the model

# %% [markdown]
# Make predictions. This is the INFERENCE phase. You make prediction over the testing set. Read the documentation of the model classes. You will find a 'predict' method.

# %%
# TO DO

# Make predictions on the testing set

# %% [markdown]
# Compute how well you performed. Calculate the accuracy over the testing set (how many you got correct over the total number of predictions).

# %%
# TO DO

#Compute how well you performed

# %% [markdown]
# Feel free to repeat now the exercise using the other model classes (SVM, K-neighbor classifier), to see which one performs better on your dataset!
